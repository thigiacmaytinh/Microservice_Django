# %%
import requests
import base64
import json

# base64 image
encoded_param = "..."  # Place your base64 format image here
    
# Prepare the parameters for the request
params = {'imageBase64': str(encoded_param)}

# Send the GET request
response = requests.post("http://localhost:88/api/yolo/detect", data=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    print(data['ret'])
else:
    # Handle the error
    print(f"Request failed with status code: {response.status_code}")
# Out:
# ['person', 'person', 'person', 'person', 'person', 'person', 'person', 'person']
